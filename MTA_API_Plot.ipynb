# %% [markdown]
# # HW7 APIs - MTA API
#
# #### Authors: Ling Lin, Xuanyu Lu, Qingyang Xiao
#
# Reference: https://github.com/nolanbconaway/underground

# %%
import os

from underground import metadata, SubwayFeed

# %%
API_KEY = '01963ec1af3debf61e88968928b647c2'
ROUTE = 'Q'

# %%
FEED_ID = metadata.get_feed_id(ROUTE)

# %%
feed = SubwayFeed.get(FEED_ID, api_key=API_KEY)

# %%
q_train_stops = feed.extract_stop_dict()[ROUTE]

# %%
q_train_stops
# Out:
# {'Q05N': [datetime.datetime(2020, 4, 6, 17, 25, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 37, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 53, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 9, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 30, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D40S': [datetime.datetime(2020, 4, 6, 17, 25, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 46, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 8, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 32, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 47, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 1, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D41S': [datetime.datetime(2020, 4, 6, 17, 27, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 49, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 10, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D42S': [datetime.datetime(2020, 4, 6, 17, 29, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 51, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 12, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 36, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 51, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 21, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D43S': [datetime.datetime(2020, 4, 6, 17, 31, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 14, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 7, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R16N': [datetime.datetime(2020, 4, 6, 17, 25, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 41, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 57, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 17, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 17, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R14N': [datetime.datetime(2020, 4, 6, 17, 28, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 44, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 0, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 20, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 20, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'B08N': [datetime.datetime(2020, 4, 6, 17, 31, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 47, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 2, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 23, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q03N': [datetime.datetime(2020, 4, 6, 17, 33, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 49, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 4, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 8, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 25, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q04N': [datetime.datetime(2020, 4, 6, 17, 35, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 51, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 7, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 44, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 1, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 11, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 27, 55, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q01N': [datetime.datetime(2020, 4, 6, 17, 32, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 47, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 8, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R20N': [datetime.datetime(2020, 4, 6, 17, 36, 51, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 12, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 56, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 13, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R17N': [datetime.datetime(2020, 4, 6, 17, 40, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 55, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 16, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D28S': [datetime.datetime(2020, 4, 6, 17, 25, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 48, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 57, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D29S': [datetime.datetime(2020, 4, 6, 17, 27, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 50, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 14, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D30S': [datetime.datetime(2020, 4, 6, 17, 28, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 50, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 44, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D31S': [datetime.datetime(2020, 4, 6, 17, 30, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 16, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 31, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 46, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D32S': [datetime.datetime(2020, 4, 6, 17, 31, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 54, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 47, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 2, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D33S': [datetime.datetime(2020, 4, 6, 17, 32, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 55, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 19, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 48, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D34S': [datetime.datetime(2020, 4, 6, 17, 34, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 57, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 5, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D35S': [datetime.datetime(2020, 4, 6, 17, 37, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 59, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 38, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 53, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D37S': [datetime.datetime(2020, 4, 6, 17, 40, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 2, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 26, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 41, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D38S': [datetime.datetime(2020, 4, 6, 17, 41, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 3, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 57, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 12, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D39S': [datetime.datetime(2020, 4, 6, 17, 43, 38, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 6, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 59, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 14, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D30N': [datetime.datetime(2020, 4, 6, 17, 26, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 47, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D29N': [datetime.datetime(2020, 4, 6, 17, 27, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 47, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 5, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 32, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 48, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D28N': [datetime.datetime(2020, 4, 6, 17, 28, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 49, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 6, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 23, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 50, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D27N': [datetime.datetime(2020, 4, 6, 17, 30, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 25, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 51, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D26N': [datetime.datetime(2020, 4, 6, 17, 31, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 26, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 36, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 53, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D25N': [datetime.datetime(2020, 4, 6, 17, 35, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 57, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D24N': [datetime.datetime(2020, 4, 6, 17, 38, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 15, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 59, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R30N': [datetime.datetime(2020, 4, 6, 17, 39, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 19, 0, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D43N': [datetime.datetime(2020, 4, 6, 17, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 1, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 27, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D42N': [datetime.datetime(2020, 4, 6, 17, 27, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 2, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 12, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D41N': [datetime.datetime(2020, 4, 6, 17, 29, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 4, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 14, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 30, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D40N': [datetime.datetime(2020, 4, 6, 17, 31, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 48, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 6, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 16, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 32, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D39N': [datetime.datetime(2020, 4, 6, 17, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 8, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D38N': [datetime.datetime(2020, 4, 6, 17, 35, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 20, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 36, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D37N': [datetime.datetime(2020, 4, 6, 17, 36, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 53, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 21, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 37, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D35N': [datetime.datetime(2020, 4, 6, 17, 38, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 56, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 13, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 23, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 39, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D34N': [datetime.datetime(2020, 4, 6, 17, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 15, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 25, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 42, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D33N': [datetime.datetime(2020, 4, 6, 17, 42, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 17, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 27, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 43, 40, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D32N': [datetime.datetime(2020, 4, 6, 17, 44, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 18, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 28, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 45, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D31N': [datetime.datetime(2020, 4, 6, 17, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 2, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 29, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 46, 10, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q01S': [datetime.datetime(2020, 4, 6, 17, 28, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 7, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 22, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 37, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R30S': [datetime.datetime(2020, 4, 6, 17, 36, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 0, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 15, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 30, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 45, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D24S': [datetime.datetime(2020, 4, 6, 17, 38, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 2, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 17, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 32, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 47, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D25S': [datetime.datetime(2020, 4, 6, 17, 40, 41, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 4, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 19, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 34, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 49, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D26S': [datetime.datetime(2020, 4, 6, 17, 45, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 9, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 24, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 39, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 54, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'D27S': [datetime.datetime(2020, 4, 6, 17, 47, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 11, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 26, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 55, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q05S': [datetime.datetime(2020, 4, 6, 17, 31, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 46, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 1, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 16, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q04S': [datetime.datetime(2020, 4, 6, 17, 33, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 48, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 3, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 18, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'Q03S': [datetime.datetime(2020, 4, 6, 17, 35, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 50, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 5, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 20, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'B08S': [datetime.datetime(2020, 4, 6, 17, 37, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 52, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 7, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 22, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R14S': [datetime.datetime(2020, 4, 6, 17, 40, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 55, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 10, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 25, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R16S': [datetime.datetime(2020, 4, 6, 17, 43, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 17, 58, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 28, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R17S': [datetime.datetime(2020, 4, 6, 17, 45, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 0, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 15, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 30, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)],
#  'R20S': [datetime.datetime(2020, 4, 6, 17, 48, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 3, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 18, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>),
#   datetime.datetime(2020, 4, 6, 18, 33, tzinfo=<DstTzInfo 'US/Eastern' EDT-1 day, 20:00:00 DST>)]}

# %% [markdown]
# ### Transform online data into python dataframe
#
# References Used:
# 1. https://thispointer.com/pandas-convert-dataframe-index-into-column-using-dataframe-reset_index-in-python/
# 2. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html
# 3. https://discuss.codecademy.com/t/can-we-add-a-new-column-at-a-specific-position-in-a-pandas-dataframe/355842
# 4. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %%
import pandas as pd

# %%
# Convert online data from dictionary format into python dataframe

Schedule = pd.DataFrame.from_dict(q_train_stops, orient='index')

# %%
# Uncomment to see what the original dataframe looks like

Schedule
# Out:
#                              0                         1  \
# Q05N 2020-04-06 17:25:38-04:00 2020-04-06 17:37:38-04:00
# D40S 2020-04-06 17:25:38-04:00 2020-04-06 17:46:23-04:00
# D41S 2020-04-06 17:27:53-04:00 2020-04-06 17:49:08-04:00
# D42S 2020-04-06 17:29:53-04:00 2020-04-06 17:51:08-04:00
# D43S 2020-04-06 17:31:23-04:00 2020-04-06 17:52:38-04:00
# R16N 2020-04-06 17:25:38-04:00 2020-04-06 17:41:51-04:00
# R14N 2020-04-06 17:28:38-04:00 2020-04-06 17:44:51-04:00
# B08N 2020-04-06 17:31:08-04:00 2020-04-06 17:47:21-04:00
# Q03N 2020-04-06 17:33:08-04:00 2020-04-06 17:49:21-04:00
# Q04N 2020-04-06 17:35:38-04:00 2020-04-06 17:51:51-04:00
# Q01N 2020-04-06 17:32:21-04:00 2020-04-06 17:47:31-04:00
# R20N 2020-04-06 17:36:51-04:00 2020-04-06 17:52:01-04:00
# R17N 2020-04-06 17:40:21-04:00 2020-04-06 17:55:31-04:00
# D28S 2020-04-06 17:25:38-04:00 2020-04-06 17:48:11-04:00
# D29S 2020-04-06 17:27:38-04:00 2020-04-06 17:50:11-04:00
# D30S 2020-04-06 17:28:08-04:00 2020-04-06 17:50:41-04:00
# D31S 2020-04-06 17:30:08-04:00 2020-04-06 17:52:41-04:00
# D32S                       NaT                       NaT
# D33S                       NaT                       NaT
# D34S                       NaT                       NaT
# D35S                       NaT                       NaT
# D37S                       NaT                       NaT
# D38S                       NaT                       NaT
# D39S                       NaT                       NaT
# D30N                       NaT                       NaT
# D29N                       NaT                       NaT
# D28N                       NaT                       NaT
# D27N                       NaT                       NaT
# D26N                       NaT                       NaT
# D25N                       NaT                       NaT
# D24N                       NaT                       NaT
# R30N                       NaT                       NaT
# D43N                       NaT                       NaT
# D42N                       NaT                       NaT
# D41N                       NaT                       NaT
# D40N                       NaT                       NaT
# D39N                       NaT                       NaT
# D38N                       NaT                       NaT
# D37N                       NaT                       NaT
# D35N                       NaT                       NaT
# D34N                       NaT                       NaT
# D33N                       NaT                       NaT
# D32N                       NaT                       NaT
# D31N                       NaT                       NaT
# Q01S                       NaT                       NaT
# R30S                       NaT                       NaT
# D24S                       NaT                       NaT
# D25S                       NaT                       NaT
# D26S                       NaT                       NaT
# D27S                       NaT                       NaT
# Q05S                       NaT                       NaT
# Q04S                       NaT                       NaT
# Q03S                       NaT                       NaT
# B08S                       NaT                       NaT
# R14S                       NaT                       NaT
# R16S                       NaT                       NaT
# R17S                       NaT                       NaT
# R20S                       NaT                       NaT
#
#                              8
# Q05N 2020-04-06 19:30:10-04:00
# D40S                       NaT
# D41S                       NaT
# D42S                       NaT
# D43S                       NaT
# R16N                       NaT
# R14N                       NaT
# B08N                       NaT
# Q03N                       NaT
# Q04N                       NaT
# Q01N                       NaT
# R20N                       NaT
# R17N                       NaT
# D28S                       NaT
# D29S                       NaT
# D30S                       NaT
# D31S                       NaT
# D32S                       NaT
# D33S                       NaT
# D34S                       NaT
# D35S                       NaT
# D37S                       NaT
# D38S                       NaT
# D39S                       NaT
# D30N                       NaT
# D29N                       NaT
# D28N                       NaT
# D27N                       NaT
# D26N                       NaT
# D25N                       NaT
# D24N                       NaT
# R30N                       NaT
# D43N                       NaT
# D42N                       NaT
# D41N                       NaT
# D40N                       NaT
# D39N                       NaT
# D38N                       NaT
# D37N                       NaT
# D35N                       NaT
# D34N                       NaT
# D33N                       NaT
# D32N                       NaT
# D31N                       NaT
# Q01S                       NaT
# R30S                       NaT
# D24S                       NaT
# D25S                       NaT
# D26S                       NaT
# D27S                       NaT
# Q05S                       NaT
# Q04S                       NaT
# Q03S                       NaT
# B08S                       NaT
# R14S                       NaT
# R16S                       NaT
# R17S                       NaT
# R20S                       NaT

# %%
# Add the index to be a new column in dataframe
# The original index is stop_id, so add stop_id to be a new column of dataframe

Schedule1 = Schedule.reset_index()

# Rename the newly added column as "stop_id"
Schedule2 = Schedule1.rename(columns={'index':'stop_id'})


# Read the last character of stop_id to identify the direction, N represents North, S represents South
Direction = []

for i in range(0, len(Schedule)):
    Direction.append(Schedule2.stop_id[i][-1])
        
# Direction

# Insert the new direction column to a specific postion, e.g. position 1 in this case
# Do not run this code the second time without rerun the above codes, 
# because it will appear an error if the column is already inserted 

Schedule2.insert(1, 'direction', Direction)

# Extract date information from the Timestamp column, create a new column and insert it to position 2
Schedule2.insert(2, 'date', Schedule2[0].dt.date)


# Another way of adding a new column to dataframe, but no specific position
# Schedule2['direction'] = Direction
# Schedule2['date'] = Schedule2[0].dt.date


# Replace the original Timestamp columns (Timestamp shows date and time) with time only

for j in range(0, len(Schedule2)):                # loop through rows
    for k in range(3, len(Schedule2.iloc[0])):       # loop through columns 
        if pd.notna(Schedule2.iloc[j, k]):              # Checking for missing value
            Schedule2.iloc[j, k] = pd.Timestamp.time(Schedule2.iloc[j, k])
            
            
# Another approach, work with dataframe that doesn't have NAs 
# Schedule2[0] = Schedule2[0].dt.time

# 20  18:53:00  19:08:00       NaT       NaT       NaT
# 21  18:56:00  19:11:00       NaT       NaT       NaT
# 22  18:57:00  19:12:00       NaT       NaT       NaT
# 23  18:59:30  19:14:30       NaT       NaT       NaT
# 24  18:31:00  18:47:40       NaT       NaT       NaT
# 25  18:32:00  18:48:40       NaT       NaT       NaT
# 26  18:33:30  18:50:10       NaT       NaT       NaT
# 27  18:35:00  18:51:40       NaT       NaT       NaT
# 28  18:36:30  18:53:10       NaT       NaT       NaT
# 29  18:40:30  18:57:10       NaT       NaT       NaT
# 30  18:42:30  18:59:10       NaT       NaT       NaT
# 31  18:44:00  19:00:40       NaT       NaT       NaT
# 32  18:27:40       NaT       NaT       NaT       NaT
# 33  18:29:10       NaT       NaT       NaT       NaT
# 34  18:30:40       NaT       NaT       NaT       NaT
# 35  18:32:40       NaT       NaT       NaT       NaT
# 36  18:34:40       NaT       NaT       NaT       NaT
# 37  18:36:40       NaT       NaT       NaT       NaT
# 38  18:37:40       NaT       NaT       NaT       NaT
# 39  18:39:40       NaT       NaT       NaT       NaT
# 40  18:42:10       NaT       NaT       NaT       NaT
# 41  18:43:40       NaT       NaT       NaT       NaT
# 42  18:45:10       NaT       NaT       NaT       NaT
# 43  18:46:10       NaT       NaT       NaT       NaT
# 44  18:37:00       NaT       NaT       NaT       NaT
# 45  18:45:30       NaT       NaT       NaT       NaT
# 46  18:47:30       NaT       NaT       NaT       NaT
# 47  18:49:30       NaT       NaT       NaT       NaT
# 48  18:54:00       NaT       NaT       NaT       NaT
# 49  18:55:30       NaT       NaT       NaT       NaT
# 50       NaT       NaT       NaT       NaT       NaT
# 51       NaT       NaT       NaT       NaT       NaT
# 52       NaT       NaT       NaT       NaT       NaT
# 53       NaT       NaT       NaT       NaT       NaT
# 54       NaT       NaT       NaT       NaT       NaT
# 55       NaT       NaT       NaT       NaT       NaT
# 56       NaT       NaT       NaT       NaT       NaT
# 57       NaT       NaT       NaT       NaT       NaT

# %% [markdown]
# ### Data Visulization
#
# References
# - https://stackoverflow.com/questions/43757820/how-to-add-a-variable-to-python-plt-title
# - https://stackoverflow.com/questions/14432557/matplotlib-scatter-plot-with-different-text-at-each-data-point

# %% [markdown]
# This plot illustrates the time gap between train arrivals for a pre-identified stop.

# %%
# Use a "magic command" to specify how we want our plots displayed
# %matplotlib notebook show dynamic/interactive plot

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Identify the stop_id that we wish to search
# In this case, we use stop 'Q05N' as the pre-identified stop

id = 'Q05N'

# %%
# Find the index that associates with the corresponding stop
index = int(Schedule2.index[Schedule2['stop_id'] == id].values)

# Find the schedule of that stop
times = Schedule2.iloc[index]

# Drop the NAs in the data
y = times.dropna()[3::]

# Set the x-values
x = range(0, len(y), 1)

# %%
# Plot size
plt.figure(figsize=(8, 5))

# Plot title
plt.title('Train Arrival Schedule of Stop: '+str(id)+' on '+str(times['date']))

# x and y labels
plt.ylabel('Time of Arrivals')
plt.xlabel('Arrivals')

# Line plot
plt.plot(x, y, 'go-')

# Lable points
for i, txt in enumerate(y):
    plt.annotate(txt, (x[i]+0.3, y[i]))

# Save plot as a png. image
plt.savefig('MTA_Plot1.png')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
